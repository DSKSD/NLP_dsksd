# %% [markdown]
# # Forward Sampling

# %%
from IPython.display import Image

# %%
Image('./image/spl_1.jpg')

# %% [markdown]
# Topological order에 따른 샘플링..? <br>
# 그 이전의 값은 샘플링에 의한 variable이 나와 있다고 가정<br>
# __Buglary__와 __Earthquake__가 F로 정해졌고 그 상태에서 P(A|B,E)는 0.001이 됌.. __Alarm__이 T로 정해졌다면 P(J|A)는 0.9, P(M|A)는 0.7..! <br>
# <br>
# 이것이 하나의 스토리로서 __인스턴스__라면 이러한 짓을 샘플링을 통해 엄청 많이 해본다..!! <br>
# <br>
# * P(E=T|MC=T)=?
#   - E=T and MC=T인 케이스를 세고, MC=T인 케이스를 센다...
#
# <br>
# 오차가 많음.(말그대로 랜덤으로 뽑기 때문..?) 엄청나게 많이 샘플링한다면 이 오차가 줄어들겠지만, 시간이 엄청 걸릴 것..

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# %matplotlib inline

# %%
pi_true = np.array([0.35, 0.45, 0.2])
mu_true = np.array([-2,1,5])
sigma_true = np.array([0.9, 0.3, .7])
col = ['b', 'r', 'g']

N = 10000
v = np.zeros((np.size(pi_true), N))
C = np.zeros(np.size(pi_true)).astype(int)
obs = np.zeros(N)
sampling = np.zeros(N)
sampling2 = np.zeros(N)

for i in range(N):
    z = np.random.random_sample()
    idx = 0
    tempSum = 0
    
    for j in range(np.size(pi_true)):
        if ((z > tempSum) & (z<=tempSum+pi_true[j])):
            idx = j
            break
        else:
            tempSum = tempSum + pi_true[j]
    
    v_temp = np.random.normal(mu_true[idx], sigma_true[idx], 1)
    C[idx] = C[idx] + 1
    v[idx, C[idx]] = v_temp
    obs[i] = v_temp
    sampling2[i] = np.random.normal(mu_true[idx], sigma_true[idx])

# %%
plt.figure(1, figsize=(7,5))
plt.hist(obs, bins=np.linspace(-10,10,(10-(-10))/0.1))
plt.show()

# %%
cnt = 0
discarded = 0
obs = np.zeros(N)
M = 100
mu_assumed = np.array([0,0,0])
sigma_assumed = np.array([1,1,1])

while cnt < N-1:
    idx = np.random.random_integers(3)-1
    sample = np.random.normal(mu_assumed[idx], sigma_assumed[idx])
    q = 1/3. * multivariate_normal.pdf(sample, mu_assumed[idx], sigma_assumed[idx])
    p = pi_true[idx] * multivariate_normal.pdf(sample, mu_true[idx], sigma_true[idx])
    u = np.random.random_sample()
    
    if u*M*q < p:
        cnt = cnt + 1
        obs[cnt] = sample
    else:
        discarded = discarded + 1
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:9: DeprecationWarning: This function is deprecated. Please call randint(1, 3 + 1) instead
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7059c84a740b> in <module>()
#       9     idx = np.random.random_integers(3)-1
#      10     sample = np.random.normal(mu_assumed[idx], sigma_assumed[idx])
# ---> 11     q = 1/3. * multivariate_normal.pdf(sample, mu_assumed[idx], sigma_assumed[idx])
#      12     p = pi_true[idx] * multivariate_normal.pdf(sample, mu_true[idx], sigma_true[idx])
#      13     u = np.random.random_sample()
#
# /usr/local/lib/python2.7/dist-packages/scipy/stats/_multivariate.pyc in pdf(self, x, mean, cov, allow_singular)
#     502         dim, mean, cov = self._process_parameters(None, mean, cov)
#     503         x = self._process_quantiles(x, dim)
# ...

# %%
plt.figure(1, figsize=(15,5))
plt.subplot(1,2,1)
plt.hist(obs, bins=np.linspace(-10,10,(10-(-10))/0.1))

plt.subplot(1,2,2)
plt.bar(range(len([cnt, discarded])), np.array([cnt, discarded]))
plt.show()

# %% [markdown]
# # Rejection Sampling

# %% [markdown]
# * __P(E=T|MC=T,A=F)=?__
# * Iterate many times!
#   - Generate a sample from the Bayesian network
#   - Buglary -> False
#   - Earthquake -> True
#   - Alarm|B=F,E=T -> True (알람이 안일어난 조건으로 추정하려고 하는데 알람이 일어난 것으로 샘플링이 됌.. 여기서 샘플링을 멈춘다. Given 파트와 검사해서 매칭되는지 보는 것. => Reject!)
#   - 다시 처음부터 샘플링.. (하다보니 Alarm이 False가 나왔다고 생각하고)
#   - JC|A=T -> True
#   - MC|A=T -> False
# * Return
# * (E=T,MC=T,A=F) 갯수/완전히 완성된 샘플링 갯수 #

# %%
Image('./image/spl_2.jpg')

# %% [markdown]
# 우리가 추정하고자 하는 Mixture distribution을 q(x)라 보고 그 분포를 모두 포괄하는(감싸는) 큰 normal 분포인 p(x)를 만들어 낸다. 유니폼 분포에서 샘플링한 값 u가 (전체 높이 M q(x)를 wrapping하기 위해..?) $ u< \frac{p(x_{(i)})}{Mq(x_{(i)})}$이면 reject한다 <br>
# <br>
# 즉, 빨간 선 안에 들어가는 것만 취급하겠다.! <br>
# <br>
# 그렇다면 M이 q(x)를 감쌀 수 있을만큼이 아니라면 무의미하다는 것? 그렇다.. M이 커져야 한다. 그렇기 때문에 여전히 좀 시간이 많이 걸린다?
# <br>
# 특히나 많은 군집을 가지는 GMM 즉, 큰 베이지안 네트워크 모델에서는 모든 봉우리를 감싸기 위해 M이 더더욱 커져야 한다..(각 봉우리의 $\mu$값을 잘 알고 있는 경우가 아니라면?) 그렇기에 이 역시 현실에서 적절한 방법은 아님

# %% [markdown]
# # Importance Sampling

# %% [markdown]
# reject 없이 목적 달성?! <br>
# <br>
# 진짜 목적은 expectation, certain probability 계산이다. (히스토그램을 그리는게 아니라..) 그러니까 이 값들만 알 수 있으면..? <br>
# <br>
# 어떤 특정 함수의 기대값(expectation)

# %%
Image('./image/spl_3.jpg')

# %% [markdown]
# $r^l = \frac{p(z^l)}{q(z^l)}$ 중요도? weight <br>
# <br>
# 어렵다..

# %% [markdown]
# ## Likelihood weighting Algorithm

# %% [markdown]
# 다시 dicrete한 도메인으로 돌아와서..!
# <br>
# * P(E=T|MC=T,A=F)=?
# * Iterate
#   - __SW=SamplongWeight = 1__
#   - Buglary -> False
#   - Earthquake -> False
#   - Alarm=F|B=F,E=F
#     -P(A=F|B=F,E=F)=0.999
#     -__SW=1x0.999__ // 얼마만큼 likelihood하게 발생할 수 있는가?
#   - JC|A=T -> true
#   - MC=T|A=F
#     - P(MC=T|A=F)=0.01
#     - SW = __1x0.999x0.01__
#   - E=T가 트루라면 SumSW+=SW(우리가 관심있는 케이스), NormSW+=SW(전체)
#   - __Return SumSW/NormSW__
